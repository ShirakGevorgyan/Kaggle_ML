# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_test = pd.read_csv('./Blueberry/test.csv')

# %%
df_train = pd.read_csv('./Blueberry/train.csv')

# %%
df_sub = pd.read_csv('./Blueberry/sample_submission.csv')

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
X = df_train.drop('yield', axis=1)
y = df_train['yield']
X_test = df_test

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# %%
model = RandomForestRegressor()

# %%
params = {
    'n_estimators' :[72,73],
    'max_depth':[6],
    'min_samples_split':[3,4,5],
    'min_samples_leaf':[4,5],
    'max_features' : [None],
     
}
grid_model = GridSearchCV(model, param_grid=params,cv=5,verbose=2)

# %% [markdown]
# grid_model.fit(X,y)

# %%
grid_model.fit(X,y)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [CV] END max_depth=6, max_features=None, max_leaf_nodes=2, max_samples=2, min_samples_leaf=4, min_samples_split=3, n_estimators=72, random_state=2; total time=   0.1s
# [CV] END max_depth=6, max_features=None, max_leaf_nodes=2, max_samples=2, min_samples_leaf=4, min_samples_split=3, n_estimators=72, random_state=2; total time=   0.0s
# [CV] END max_depth=6, max_features=None, max_leaf_nodes=2, max_samples=2, min_samples_leaf=4, min_samples_split=3, n_estimators=72, random_state=2; total time=   0.0s
# [CV] END max_depth=6, max_features=None, max_leaf_nodes=2, max_samples=2, min_samples_leaf=4, min_samples_split=3, n_estimators=72, random_state=2; total time=   0.0s
# [CV] END max_depth=6, max_features=None, max_leaf_nodes=2, max_samples=2, min_samples_leaf=4, min_samples_split=3, n_estimators=72, random_state=2; total time=   0.1s
# ...

# %%
grid_model.best_params_
# Out:
# {'max_depth': 6,
#  'max_features': None,
#  'min_samples_leaf': 5,
#  'min_samples_split': 3,
#  'n_estimators': 73}

# %%
grid_model.best_params_
# Out:
# {'max_depth': 6,
#  'max_features': None,
#  'min_samples_leaf': 5,
#  'min_samples_split': 3,
#  'n_estimators': 73}

# %%
grid_model.best_params_
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'absolute_error',
#  'max_depth': 6,
#  'max_features': None,
#  'max_leaf_nodes': 2,
#  'max_samples': 5,
#  'min_samples_leaf': 5,
#  'min_samples_split': 3,
#  'n_estimators': 73,
#  'n_jobs': 3,
#  'random_state': 2,
#  'verbose': 4,
#  'warm_start': False}

# %%
y_pred = grid_model.predict(X_test)

# %%
df_sub['yield'] = y_pred

# %%
df_sub.to_csv('ful.csv', index=False, index_label=False)
