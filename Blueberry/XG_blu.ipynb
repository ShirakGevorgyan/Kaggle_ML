# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Using cached xgboost-2.0.3-py3-none-win_amd64.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy in c:\users\user\desktop\ml\venv\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\user\desktop\ml\venv\lib\site-packages (from xgboost) (1.13.0)
# Using cached xgboost-2.0.3-py3-none-win_amd64.whl (99.8 MB)
# Installing collected packages: xgboost
# Successfully installed xgboost-2.0.3

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_test = pd.read_csv('test.csv')
df_train = pd.read_csv('train.csv')

# %%
df_test = df_test.drop(['id'], axis=1)
df_train = df_train.drop(['id'], axis=1)

# %%
# for i in df_train.columns:
#     p_75 = float(df_train.describe()[i].loc['75%'])
#     p_25 = float(df_train.describe()[i].loc['25%'])
#     IQR = float(df_train.describe()[i].loc['75%']) - float(df_train.describe()[i].loc['25%'])
#     df_train[i] = df_train[i].apply(lambda x : np.mean(df_train[i]) if x < p_25 - IQR * 1.5 or x > p_75 + IQR * 1.5 else x)

# %%
# for i in df_test.columns:
#     p_75 = float(df_test.describe()[i].loc['75%'])
#     p_25 = float(df_test.describe()[i].loc['25%'])
#     IQR = float(df_test.describe()[i].loc['75%']) - float(df_test.describe()[i].loc['25%'])
#     df_test[i] = df_test[i].apply(lambda x : np.mean(df_test[i]) if x < p_25 - IQR * 1.5 or x > p_75 + IQR * 1.5 else x)

# %%
df_train
# Out:
#         Row#  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0      450.0       12.5      0.25     0.38     0.38   0.75              86.0
# 1       14.0       37.5      0.75     0.25     0.25   0.50              86.0
# 2      327.0       12.5      0.25     0.25     0.75   0.75              94.6
# 3      554.0       25.0      0.50     0.25     0.63   0.50              86.0
# 4      685.0       25.0      0.50     0.38     0.38   0.75              94.6
# ...      ...        ...       ...      ...      ...    ...               ...
# 14995  690.0       25.0      0.50     0.38     0.38   0.75              86.0
# 14996  757.0       25.0      0.50     0.38     0.63   0.50              86.0
# 14997  109.0       12.5      0.25     0.25     0.25   0.63              69.7
# 14998  583.0       25.0      0.50     0.25     0.63   0.75              69.7
# 14999  589.0       25.0      0.50     0.25     0.63   0.63              77.4
#
#        MinOfUpperTRange  AverageOfUpperTRange  MaxOfLowerTRange  \
# 0                  52.0                  71.9              62.0
# 1                  52.0                  71.9              62.0
# 2                  57.2                  79.0              68.2
# 3                  52.0                  71.9              62.0
# 4                  57.2                  79.0              68.2
# ...                 ...                   ...               ...
# 14995              52.0                  71.9              62.0
# 14996              52.0                  71.9              62.0
# 14997              42.1                  58.2              50.2
# 14998              42.1                  58.2              50.2
# 14999              46.8                  64.7              55.8
#
#        MinOfLowerTRange  AverageOfLowerTRange  RainingDays  \
# 0                  30.0                  50.8    18.705751
# 1                  30.0                  50.8    16.000000
# 2                  33.0                  55.9    24.000000
# 3                  30.0                  50.8    24.000000
# 4                  33.0                  55.9    16.000000
# ...                 ...                   ...          ...
# 14995              30.0                  50.8    18.705751
# 14996              30.0                  50.8    34.000000
# 14997              24.3                  41.2    34.000000
# 14998              24.3                  41.2    16.000000
# 14999              27.0                  45.8    24.000000
#
#        AverageRainingDays  fruitset  fruitmass      seeds       yield
# 0                    0.10  0.527309   0.464892  37.021772  6620.09877
# 1                    0.26  0.353236   0.383564  27.621548  3662.18313
# 2                    0.39  0.510103   0.461904  37.970243  6015.22456
# 3                    0.39  0.483249   0.445475  34.531142  5741.21030
# 4                    0.26  0.419851   0.420094  32.849238  4813.45285
# ...                   ...       ...        ...        ...         ...
# 14995                0.10  0.502398   0.453120  36.311593  6254.82922
# 14996                0.56  0.428322   0.408851  31.078830  4867.94772
# 14997                0.56  0.398218   0.404576  31.665598  4016.36160
# 14998                0.26  0.509001   0.415971  36.554327  6292.96076
# 14999                0.39  0.402052   0.402856  31.607332  4203.02762
#
# [15000 rows x 18 columns]

# %%
import xgboost as xgb
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV

# %%
X = df_train.drop('yield', axis=1)
y = df_train['yield']

# %%
from sklearn.preprocessing import StandardScaler

# %%
sceler = StandardScaler()

# %%
# X = sceler.fit_transform(X)

# %%
model = XGBRegressor(objective='reg:squarederror')

# %%
param_grid = {
    'n_estimators': [100, 120, 150],
    'max_depth': [3, 4, 5],
    'learning_rate': [0.05, 0.1, 0.15],
    'subsample': [0.5, 0.6, 0.7],
    'colsample_bytree': [0.75, 0.8, 0.85],
}

# %%
full_model = GridSearchCV(model, param_grid, cv=3, verbose=1, n_jobs=-1)

# %%
X
# Out:
#         Row#  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0      450.0       12.5      0.25     0.38     0.38   0.75              86.0
# 1       14.0       37.5      0.75     0.25     0.25   0.50              86.0
# 2      327.0       12.5      0.25     0.25     0.75   0.75              94.6
# 3      554.0       25.0      0.50     0.25     0.63   0.50              86.0
# 4      685.0       25.0      0.50     0.38     0.38   0.75              94.6
# ...      ...        ...       ...      ...      ...    ...               ...
# 14995  690.0       25.0      0.50     0.38     0.38   0.75              86.0
# 14996  757.0       25.0      0.50     0.38     0.63   0.50              86.0
# 14997  109.0       12.5      0.25     0.25     0.25   0.63              69.7
# 14998  583.0       25.0      0.50     0.25     0.63   0.75              69.7
# 14999  589.0       25.0      0.50     0.25     0.63   0.63              77.4
#
#        MinOfUpperTRange  AverageOfUpperTRange  MaxOfLowerTRange  \
# 0                  52.0                  71.9              62.0
# 1                  52.0                  71.9              62.0
# 2                  57.2                  79.0              68.2
# 3                  52.0                  71.9              62.0
# 4                  57.2                  79.0              68.2
# ...                 ...                   ...               ...
# 14995              52.0                  71.9              62.0
# 14996              52.0                  71.9              62.0
# 14997              42.1                  58.2              50.2
# 14998              42.1                  58.2              50.2
# 14999              46.8                  64.7              55.8
#
#        MinOfLowerTRange  AverageOfLowerTRange  RainingDays  \
# 0                  30.0                  50.8    18.705751
# 1                  30.0                  50.8    16.000000
# 2                  33.0                  55.9    24.000000
# 3                  30.0                  50.8    24.000000
# 4                  33.0                  55.9    16.000000
# ...                 ...                   ...          ...
# 14995              30.0                  50.8    18.705751
# 14996              30.0                  50.8    34.000000
# 14997              24.3                  41.2    34.000000
# 14998              24.3                  41.2    16.000000
# 14999              27.0                  45.8    24.000000
#
#        AverageRainingDays  fruitset  fruitmass      seeds
# 0                    0.10  0.527309   0.464892  37.021772
# 1                    0.26  0.353236   0.383564  27.621548
# 2                    0.39  0.510103   0.461904  37.970243
# 3                    0.39  0.483249   0.445475  34.531142
# 4                    0.26  0.419851   0.420094  32.849238
# ...                   ...       ...        ...        ...
# 14995                0.10  0.502398   0.453120  36.311593
# 14996                0.56  0.428322   0.408851  31.078830
# 14997                0.56  0.398218   0.404576  31.665598
# 14998                0.26  0.509001   0.415971  36.554327
# 14999                0.39  0.402052   0.402856  31.607332
#
# [15000 rows x 17 columns]

# %%
full_model.fit(X,y)
# Out:
# Fitting 3 folds for each of 243 candidates, totalling 729 fits
# GridSearchCV(cv=3,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'colsample_bytree': [0.75, 0.8, 0.85],
#                          'learning_rate': [0.05, 0.1, 0.15],
#                          'max_depth': [3, 4, 5],
#                          'n_estimators': [100, 120, 150],
#                          'subsample': [0.5, 0.6, 0.7]},
#              verbose=1)

# %%
full_model.best_params_
# Out:
# {'colsample_bytree': 0.85,
#  'learning_rate': 0.05,
#  'max_depth': 5,
#  'n_estimators': 150,
#  'subsample': 0.6}

# %%
full_model.best_params_
# Out:
# {'colsample_bytree': 0.85,
#  'learning_rate': 0.05,
#  'max_depth': 5,
#  'n_estimators': 150,
#  'subsample': 0.6}

# %%
y_pred = full_model.predict(df_test)

# %%
df_sub = pd.read_csv('sample_submission.csv')

# %%
df_sub['yield'] = y_pred

# %%
df_sub.to_csv('xg.csv', index=False, index_label=False)
